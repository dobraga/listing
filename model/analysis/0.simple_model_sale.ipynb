# %%
# %load_ext autoreload
# %autoreload 2

# %%
from experiments.extract import extract
from experiments.experiment import Experiment
from experiments.polar import LatLonPolar

import pandas as pd
import altair as alt
from lightgbm import LGBMRegressor

from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import KBinsDiscretizer, OneHotEncoder
from category_encoders import TargetEncoder, QuantileEncoder

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Data Sample

# %%
X = extract('SALE')
X['month'] = pd.to_datetime(X.created_date.dt.strftime('%Y-%m-01'))
print(X.shape)
X.sample(5).T
# Out:
# (4985, 14)
# title                                                Casa de Condomínio com dois quartos , na Rua Barão de Piraquara - Realengo.  \
# url            /imovel/venda-casa-de-condominio-2-quartos-com-cozinha-realengo-zona-oeste-rio-de-janeiro-rj-140m2-id-2595453461/
# origin                                                                                                                zapimoveis
# neighborhood                                             Realengo
# usable_area                                                   140
# unit_types                                                   HOME
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       2
# suites                                                          0
# parking_spaces                                                  0
# amenities                                                 KITCHEN
# lat                                                        -22.88
# lon                                                        -43.44
# total                                                  275,020.00
# created_date                     2022-11-25 21:46:05.985000+00:00
# month                                         2022-11-01 00:00:00
#
# title                                                                           Apartamento-À VENDA-Praça Seca-Rio de Janeiro-RJ  \
# url            /imovel/venda-apartamento-2-quartos-com-churrasqueira-praca-seca-zona-oeste-rio-de-janeiro-rj-52m2-id-2582558660/
# origin                                                                                                                zapimoveis
# neighborhood                                           Praça Seca
# usable_area                                                    52
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       1
# suites                                                          0
# parking_spaces                                                  1
# amenities                               BARBECUE_GRILL|PARTY_HALL
# lat                                                        -22.90
# lon                                                        -43.34
# total                                                  149,400.00
# created_date                     2022-09-29 05:53:14.118000+00:00
# month                                         2022-09-01 00:00:00
#
# title                                              Apartamento à venda, 62 m² por R$ 235.000,00 - Praça Seca - Rio de Janeiro/RJ  \
# url            /imovel/apartamento-2-quartos-praca-seca-zona-oeste-rio-de-janeiro-com-garagem-62m2-venda-RS235000-id-2574150606/
# origin                                                                                                                  vivareal
# neighborhood                                           Praça Seca
# usable_area                                                    62
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       2
# suites                                                          1
# parking_spaces                                                  1
# amenities       POOL|BARBECUE_GRILL|BACKYARD|SERVICE_AREA|SPOR...
# lat                                                          0.00
# lon                                                          0.00
# total                                                  235,450.00
# created_date                     2022-08-02 02:01:49.522000+00:00
# month                                         2022-08-01 00:00:00
#
# title                                            REALENGO - EXCLUSIVIDADE. MARAVILHOSO IMÓVEL DUPLEX EM CONDOMINIO  \
# url            /imovel/venda-casa-4-quartos-com-piscina-realengo-zona-oeste-rio-de-janeiro-rj-180m2-id-2586622319/
# origin                                                                                                  zapimoveis
# neighborhood                                             Realengo
# usable_area                                                   180
# unit_types                                                   HOME
# floors                                                          0
# bedrooms                                                        4
# bathrooms                                                       5
# suites                                                          3
# parking_spaces                                                  3
# amenities                                     BARBECUE_GRILL|POOL
# lat                                                          0.00
# lon                                                          0.00
# total                                                  480,050.00
# created_date                     2022-10-22 01:35:39.919000+00:00
# month                                         2022-10-01 00:00:00
#
# title                                                                           Praça Seca | Apartamento 3 quartos, sendo 1 suite
# url            /imovel/apartamento-3-quartos-praca-seca-zona-oeste-rio-de-janeiro-com-garagem-116m2-venda-RS400000-id-2646784776/
# origin                                                                                                                   vivareal
# neighborhood                                           Praça Seca
# usable_area                                                   116
# unit_types                                              APARTMENT
# floors                                                          6
# bedrooms                                                        3
# bathrooms                                                       3
# suites                                                          1
# parking_spaces                                                  2
# amenities       ELEVATOR|BALCONY|GARAGE|SERVICE_AREA|NEAR_ACCE...
# lat                                                          0.00
# lon                                                          0.00
# total                                                  401,043.00
# created_date                     2023-07-28 04:37:48.908000+00:00
# month                                         2023-07-01 00:00:00

# %% [markdown]
# # Simple Model

# %%
y = X.pop('total')
exp = Experiment(X, y, 5)
exp
# Out:
# Experiment(n_splits=5, metrics=[<function mean_absolute_error at 0x7fbf234ee830>, <function rmse at 0x7fbf230136d0>, <function mean_absolute_percentage_error at 0x7fbf234ee950>])

# %%
simple_pipe = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces'])
)
exp_simple_pipe = exp.run('simple', LGBMRegressor(), {}, simple_pipe)


simple_pipe_unit = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces']),
    (OneHotEncoder(), ['unit_types'])
)
exp_pipe_unit = exp.run('unit', LGBMRegressor(), {}, simple_pipe_unit)

simple_pipe_latlon = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (OneHotEncoder(), ['unit_types'])
)
exp_pipe_latlon = exp.run('latlng', LGBMRegressor(), {}, simple_pipe_latlon)

simple_pipe_neighborhood = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (OneHotEncoder(handle_unknown='ignore'), ['neighborhood', 'unit_types'])
)
exp_pipe_neighborhood = exp.run('neighborhood', LGBMRegressor(), {}, simple_pipe_neighborhood)

simple_pipe_target = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (TargetEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_target = exp.run('neighborhood_target', LGBMRegressor(), {}, simple_pipe_target)

simple_pipe_quantile = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (QuantileEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_quantile = exp.run('neighborhood_quantile', LGBMRegressor(), {}, simple_pipe_quantile)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.mean().unstack().sort_values('mae')
# Out:
# metric                       mae  mape         rmse
# name
# unit                  181,365.40  0.66 2,168,224.99
# simple                182,350.53  0.66 2,169,298.40
# neighborhood          200,665.21  0.88 2,414,209.80
# latlng                200,977.56  0.89 2,416,006.77
# neighborhood_quantile 201,282.70  0.89 2,419,201.18
# neighborhood_target   201,396.43  0.89 2,416,428.03

# %%
polar_target = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces']),
    (LatLonPolar('neighborhood'), ['neighborhood', 'lat', 'lon']),
    (TargetEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_target = exp.run('polar_target', LGBMRegressor(), {}, polar_target)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.mean().unstack().sort_values('mae')
# Out:
# metric                       mae  mape         rmse
# name
# unit                  181,365.40  0.66 2,168,224.99
# simple                182,350.53  0.66 2,169,298.40
# neighborhood          200,665.21  0.88 2,414,209.80
# latlng                200,977.56  0.89 2,416,006.77
# neighborhood_quantile 201,282.70  0.89 2,419,201.18
# neighborhood_target   201,396.43  0.89 2,416,428.03
# polar_target          217,857.49  0.92 2,421,334.28

# %%
def clip_target(X, y, quantiles=[.05, .95]):
    qinf = y.quantile(quantiles[0])
    qsup = y.quantile(quantiles[1])
    return X, y.clip(lower=qinf, upper=qsup)

exp_clipped_latlon = exp.run('clipped latlng', LGBMRegressor(), {}, simple_pipe_target, preprocess_train_fn=clip_target)

exp_clipped_neighborhood = exp.run('clipped neighborhood', LGBMRegressor(), {}, simple_pipe_neighborhood, preprocess_train_fn=clip_target)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.median().unstack().sort_values('mae')
# Out:
# metric                       mae  mape         rmse
# name
# clipped latlng         70,626.24  0.21   193,740.23
# clipped neighborhood   70,968.62  0.21   194,414.03
# unit                  141,477.63  0.71   645,289.27
# simple                142,768.17  0.71   649,973.43
# neighborhood_target   209,686.09  0.75 1,841,526.47
# latlng                209,789.91  0.76 1,842,615.03
# neighborhood          210,968.54  0.73 1,830,612.07
# neighborhood_quantile 211,128.55  0.74 1,843,577.65
# polar_target          224,621.71  0.85 1,443,477.95

# %%
base = alt.Chart(
    exp.obs_metrics.assign(name = exp.obs_metrics.metric + ' | ' + exp.obs_metrics.name + ' | ' + exp.obs_metrics.split_name).query('metric == "mape"')
)

selection = alt.selection_multi(fields=['name'], bind='legend')
opacity = alt.condition(selection, alt.value(1.0), alt.value(0))

(
    base.mark_point().encode(x = 'split', y = 'value', color = 'name', tooltip = ['name', 'value'], opacity = opacity) + 
    base.mark_line().encode(x = 'split', y = 'value', color = 'name', opacity = opacity)
).add_selection(selection).properties(width=900, height=600).interactive(bind_x = False)
# Out:
# alt.LayerChart(...)

# %%
y_pred = exp_clipped_latlon.predict(X, y)
points = [0] + [i.right for i in pd.qcut(y, 15).cat.categories.values]

pd.DataFrame({
    'true': pd.cut(y, points).tolist(),
    'pred': pd.cut(y_pred, points).tolist()
}).groupby(['true', 'pred'])\
.value_counts().unstack().fillna(0).astype(int)\
.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_d8864_row0_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_d8864_row0_col1, #T_d8864_row1_col2, #T_d8864_row2_col2, #T_d8864_row3_col3, #T_d8864_row3_col6, #T_d8864_row4_col6, #T_d8864_row5_col6, #T_d8864_row6_col6, #T_d8864_row7_col7, #T_d8864_row8_col8, #T_d8864_row9_col9, #T_d8864_row10_col11, #T_d8864_row11_col11, #T_d8864_row12_col13, #T_d8864_row13_col13, #T_d8864_row14_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d8864_row0_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d8864_row0_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_d8864_row0_col4, #T_d8864_row4_col5 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_d8864_row0_col5, #T_d8864_row2_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d8864_row0_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_d8864_row0_col7, #T_d8864_row9_col3, #T_d8864_row9_col13 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d8864_row0_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_d8864_row0_col9, #T_d8864_row0_col13, #T_d8864_row0_col14, #T_d8864_row1_col11, #T_d8864_row1_col13, #T_d8864_row1_col14, #T_d8864_row2_col13, #T_d8864_row2_col14, #T_d8864_row3_col13, #T_d8864_row3_col14, #T_d8864_row4_col0, #T_d8864_row4_col13, #T_d8864_row4_col14, #T_d8864_row5_col0, #T_d8864_row6_col0, #T_d8864_row6_col11, #T_d8864_row6_col14, #T_d8864_row7_col0, #T_d8864_row7_col13, #T_d8864_row7_col14, #T_d8864_row8_col0, #T_d8864_row8_col2, #T_d8864_row8_col14, #T_d8864_row9_col0, #T_d8864_row9_col1, #T_d8864_row9_col14, #T_d8864_row10_col0, #T_d8864_row10_col1, #T_d8864_row10_col3, #T_d8864_row11_col0, #T_d8864_row11_col1, #T_d8864_row11_col2, #T_d8864_row11_col4, #T_d8864_row11_col5, #T_d8864_row11_col14, #T_d8864_row12_col0, #T_d8864_row12_col1, #T_d8864_row12_col2, #T_d8864_row12_col4, #T_d8864_row12_col14, #T_d8864_row13_col0, #T_d8864_row13_col1, #T_d8864_row13_col2, #T_d8864_row13_col3, #T_d8864_row13_col4, #T_d8864_row13_col5, #T_d8864_row14_col0, #T_d8864_row14_col2, #T_d8864_row14_col6, #T_d8864_row14_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d8864_row0_col10, #T_d8864_row0_col11, #T_d8864_row0_col12, #T_d8864_row1_col12, #T_d8864_row4_col11, #T_d8864_row5_col11, #T_d8864_row5_col12, #T_d8864_row5_col13, #T_d8864_row5_col14, #T_d8864_row10_col2, #T_d8864_row12_col3, #T_d8864_row12_col5, #T_d8864_row13_col6, #T_d8864_row13_col7, #T_d8864_row14_col8 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d8864_row1_col0, #T_d8864_row1_col7, #T_d8864_row12_col9 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d8864_row1_col1, #T_d8864_row8_col7 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_d8864_row1_col3 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_d8864_row1_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_d8864_row1_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_d8864_row1_col6 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d8864_row1_col8, #T_d8864_row1_col9, #T_d8864_row2_col12, #T_d8864_row5_col10 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_d8864_row1_col10, #T_d8864_row2_col11, #T_d8864_row3_col0, #T_d8864_row3_col10, #T_d8864_row3_col11, #T_d8864_row3_col12, #T_d8864_row4_col10, #T_d8864_row4_col12, #T_d8864_row6_col13, #T_d8864_row7_col1, #T_d8864_row8_col1, #T_d8864_row8_col3, #T_d8864_row8_col12, #T_d8864_row9_col2, #T_d8864_row13_col9, #T_d8864_row13_col14 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d8864_row2_col0, #T_d8864_row4_col1, #T_d8864_row5_col1, #T_d8864_row6_col1, #T_d8864_row8_col13, #T_d8864_row10_col4, #T_d8864_row10_col5, #T_d8864_row10_col14, #T_d8864_row12_col7, #T_d8864_row13_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d8864_row2_col1, #T_d8864_row11_col10 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_d8864_row2_col3 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_d8864_row2_col4, #T_d8864_row9_col10 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_d8864_row2_col5, #T_d8864_row2_col8, #T_d8864_row3_col1, #T_d8864_row4_col8, #T_d8864_row6_col10, #T_d8864_row11_col7 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_d8864_row2_col6 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_d8864_row2_col7, #T_d8864_row6_col2, #T_d8864_row10_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_d8864_row2_col10, #T_d8864_row6_col12, #T_d8864_row7_col2, #T_d8864_row13_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d8864_row3_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_d8864_row3_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_d8864_row3_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_d8864_row3_col7 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_d8864_row3_col8 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d8864_row3_col9, #T_d8864_row7_col11, #T_d8864_row8_col11 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d8864_row4_col2, #T_d8864_row10_col12 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_d8864_row4_col3, #T_d8864_row5_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_d8864_row4_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_d8864_row4_col7 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_d8864_row4_col9 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d8864_row5_col2, #T_d8864_row7_col5, #T_d8864_row8_col4, #T_d8864_row13_col11 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_d8864_row5_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_d8864_row5_col4, #T_d8864_row6_col9, #T_d8864_row11_col8 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_d8864_row5_col5, #T_d8864_row10_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_d8864_row5_col8 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_d8864_row5_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d8864_row6_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_d8864_row6_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_d8864_row6_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_d8864_row6_col7 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_d8864_row6_col8 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_d8864_row7_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_d8864_row7_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_d8864_row7_col6 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d8864_row7_col8 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_d8864_row7_col9 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_d8864_row7_col10, #T_d8864_row12_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d8864_row7_col12, #T_d8864_row11_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_d8864_row8_col5, #T_d8864_row12_col10 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_d8864_row8_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_d8864_row8_col9, #T_d8864_row9_col7, #T_d8864_row11_col12 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_d8864_row8_col10, #T_d8864_row9_col12 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_d8864_row9_col4, #T_d8864_row14_col9, #T_d8864_row14_col10 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d8864_row9_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d8864_row9_col6 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_d8864_row9_col8 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_d8864_row9_col11 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_d8864_row10_col7 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_d8864_row10_col9 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_d8864_row10_col10 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_d8864_row10_col13 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_d8864_row11_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_d8864_row11_col9 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_d8864_row11_col13 {
#   background

# %%
pd.DataFrame({
    'feature': sum(exp_clipped_latlon.model[:-1][0]._columns, []),
    'imp': exp_clipped_latlon.model._final_estimator.feature_importances_
}).sort_values('imp', ascending=False)
# Out:
#           feature   imp
# 0     usable_area  1190
# 5             lon   514
# 4             lat   499
# 3  parking_spaces   236
# 2       bathrooms   211
# 1        bedrooms   199
# 7      unit_types    78
# 6    neighborhood    73

# %%
import m2cgen as m2c

code = m2c.export_to_go(exp_clipped_neighborhood.model._final_estimator, function_name='Predict')
code
# Out:
# 'func Predict(input []float64) float64 {\n    var var0 float64\n    if input[0] > 102.50000000000001 {\n        if input[0] > 144.50000000000003 {\n            if input[0] > 316.00000000000006 {\n                var0 = 291794.9429328361\n            } else {\n                if input[1] > 2.5000000000000004 {\n                    if input[4] <= -22.901590347290036 {\n                        var0 = 272040.43401466217\n                    } else {\n                        if input[0] > 145.50000000000003 {\n                            if input[0] > 151.00000000000003 {\n                                if input[0] > 156.50000000000003 {\n                                    if input[3] > 2.5000000000000004 {\n                                        var0 = 288629.3462768541\n                                    } else {\n                                        var0 = 283681.7121321369\n                                    }\n                                } else {\n                                    var0 = 292641.2482337377\n                                }\n                            } else {\n                                var0 = 277047.70473113353\n                            }\n                        } else {\n                            var0 = 292302.6604026365\n                        }\n                    }\n                } else {\n                    if input[4] <= -22.877845764160153 {\n                        var0 = 278683.59813160554\n                    } else {\n                        var0 = 270682.6863862713\n                    }\n                }\n            }\n        } else {\n            if input[5] <= -43.34317016601562 {\n                if input[1] > 2.5000000000000004 {\n                    var0 = 274956.3413729479\n                } else {\n                    var0 = 267360.22805225983\n                }\n            } else {\n                if input[0] > 126.00000000000001 {\n                    if input[0] > 139.50000000000003 {\n                        var0 = 274538.3811711563\n                    } else {\n                        var0 = 283215.36081473756\n                    }\n                } else {\n                    if input[3] > 1.5000000000000002 {\n                        var0 = 280613.7609384229\n                    } else {\n                        var0 = 271986.4297841495\n                    }\n                }\n            }\n        }\n    } else {\n        if input[0] > 60.50000000000001 {\n            if input[0] > 75.50000000000001 {\n                if input[1] > 2.5000000000000004 {\n                    if input[10] > 0.000000000000000000000000000000000010000000180025095 {\n                        var0 = 267052.51923186175\n                    } else {\n                        if input[2] > 2.5000000000000004 {\n                            var0 = 280129.2670184599\n                        } else {\n                            if input[0] > 87.50000000000001 {\n                                var0 = 268072.2780070756\n                            } else {\n                                var0 = 275124.75227691646\n                            }\n                        }\n                    }\n                } else {\n                    if input[3] > 0.000000000000000000000000000000000010000000180025095 {\n                        if input[4] <= -22.90091800689697 {\n                            var0 = 258943.38218165436\n                        } else {\n                            var0 = 266319.98658559646\n                        }\n                    } else {\n                        var0 = 259674.4200495664\n                    }\n                }\n            } else {\n                if input[4] <= -22.902986526489254 {\n                    var0 = 254129.44489389393\n                } else {\n                    if input[4] <= -22.901232719421383 {\n                        var0 = 267160.3687920887\n                    } else {\n                        if input[4]  ...
