# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model.extract import extract
from experiments.experiment import Experiment
from experiments.polar import LatLonPolar

import pandas as pd
import altair as alt
from lightgbm import LGBMRegressor

from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import KBinsDiscretizer, OneHotEncoder
from category_encoders import TargetEncoder, QuantileEncoder

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Data Sample

# %%
X = extract('RENTAL')
X['month'] = pd.to_datetime(X.created_date.dt.strftime('%Y-%m-01'))
print(X.shape)
X.sample(5).T
# Out:
# (34486, 14)
# title                                                                       Apartamento estilo Loft Centro na Lapa  \
# url            /imovel/apartamento-1-quartos-centro-zona-central-rio-de-janeiro-40m2-aluguel-RS1100-id-2594569902/
# origin                                                                                                    vivareal
# neighborhood                                               Centro
# usable_area                                                    40
# unit_types                                              APARTMENT
# floors                                                         10
# bedrooms                                                        1
# bathrooms                                                       1
# suites                                                          0
# parking_spaces                                                  0
# amenities       DISABLED_ACCESS|GATED_COMMUNITY|ELECTRONIC_GAT...
# lat                                                        -22.91
# lon                                                        -43.18
# total                                                    1,515.00
# created_date                     2022-11-22 20:03:53.780000+00:00
# month                                         2022-11-01 00:00:00
#
# title                                                           Oportunidade Imperdível no Coração da Tijuca!  \
# url            /imovel/aluguel-apartamento-2-quartos-tijuca-zona-norte-rio-de-janeiro-rj-100m2-id-2604719781/
# origin                                                                                             zapimoveis
# neighborhood                                               Tijuca
# usable_area                                                   100
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       3
# suites                                                          1
# parking_spaces                                                  1
# amenities
# lat                                                          0.00
# lon                                                          0.00
# total                                                    3,800.00
# created_date                     2023-01-10 10:49:24.282000+00:00
# month                                         2023-01-01 00:00:00
#
# title                                                                   Apartamento para Aluguel - Taquara, 2 Quartos, 42 m2  \
# url            /imovel/apartamento-2-quartos-taquara-zona-oeste-rio-de-janeiro-com-garagem-42m2-aluguel-RS990-id-2622525892/
# origin                                                                                                              vivareal
# neighborhood                                              Taquara
# usable_area                                                    42
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       1
# suites                                                          0
# parking_spaces                                                  1
# amenities                          GARAGE|SPORTS_COURT|PARTY_HALL
# lat                                                          0.00
# lon                                                          0.00
# total                                                    1,350.00
# created_date                     2023-04-03 15:12:39.524000+00:00
# month                                         2023-04-01 00:00:00
#
# title                                                                        Recreio dos Bandeirantes | Apartamento 4 quartos, sendo 3 suites  \
# url            /imovel/aluguel-apartamento-4-quartos-com-interfone-recreio-dos-bandeirantes-zona-oeste-rio-de-janeiro-rj-172m2-id-2582913516/
# origin                                                                                                                             zapimoveis
# neighborhood                             Recreio Dos Bandeirantes
# usable_area                                                   172
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        4
# bathrooms                                                       4
# suites                                                          3
# parking_spaces                                                  3
# amenities                                 INTERCOM|SAFETY_CIRCUIT
# lat                                                          0.00
# lon                                                          0.00
# total                                                    6,220.00
# created_date                     2022-10-01 06:17:32.482000+00:00
# month                                         2022-10-01 00:00:00
#
# title                                               Apartamento para aluguel com 65 metros quadrados com 2 quartos
# url            /imovel/apartamento-2-quartos-maracana-zona-norte-rio-de-janeiro-65m2-aluguel-RS1300-id-2531069409/
# origin                                                                                                    vivareal
# neighborhood                                             Maracanã
# usable_area                                                    65
# unit_types                                              APARTMENT
# floors                                                          0
# bedrooms                                                        2
# bathrooms                                                       1
# suites                                                          0
# parking_spaces                                                  0
# amenities
# lat                                                        -22.91
# lon                                                        -43.22
# total                                                    2,000.00
# created_date                     2021-08-17 19:59:31.687000+00:00
# month                                         2021-08-01 00:00:00

# %% [markdown]
# # Simple Model

# %%
y = X.pop('total')
exp = Experiment(X, y, 5)
exp
# Out:
# Experiment(n_splits=5, metrics=[<function mean_absolute_error at 0x7f285d641e10>, <function rmse at 0x7f285d6aacb0>, <function mean_absolute_percentage_error at 0x7f285d641f30>])

# %%
simple_pipe = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces'])
)
exp_simple_pipe = exp.run('simple', LGBMRegressor(), {}, simple_pipe)


simple_pipe_unit = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces']),
    (OneHotEncoder(), ['unit_types'])
)
exp_pipe_unit = exp.run('unit', LGBMRegressor(), {}, simple_pipe_unit)

simple_pipe_latlon = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (OneHotEncoder(), ['unit_types'])
)
exp_pipe_latlon = exp.run('latlng', LGBMRegressor(), {}, simple_pipe_latlon)

simple_pipe_neighborhood = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (OneHotEncoder(handle_unknown='ignore'), ['neighborhood', 'unit_types'])
)
exp_pipe_neighborhood = exp.run('neighborhood', LGBMRegressor(), {}, simple_pipe_neighborhood)

simple_pipe_target = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (TargetEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_target = exp.run('neighborhood_target', LGBMRegressor(), {}, simple_pipe_target)

simple_pipe_quantile = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces', 'lat', 'lon']),
    (QuantileEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_quantile = exp.run('neighborhood_quantile', LGBMRegressor(), {}, simple_pipe_quantile)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.mean().unstack().sort_values('mae')
# Out:
# metric                     mae  mape      rmse
# name
# neighborhood          2,609.91  0.50 20,267.21
# neighborhood_target   2,629.03  0.49 19,865.10
# neighborhood_quantile 2,666.86  0.52 19,902.39
# latlng                2,995.75  0.59 21,425.96
# unit                  3,055.20  0.63 22,509.97
# simple                3,135.44  0.64 22,565.79

# %%
polar_target = make_column_transformer(
    ('passthrough', ['usable_area', 'bedrooms', 'bathrooms', 'parking_spaces']),
    (LatLonPolar('neighborhood'), ['neighborhood', 'lat', 'lon']),
    (TargetEncoder(), ['neighborhood', 'unit_types'])
)
exp_pipe_target = exp.run('polar_target', LGBMRegressor(), {}, polar_target)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.mean().unstack().sort_values('mae')
# Out:
# metric                     mae  mape      rmse
# name
# neighborhood          2,609.91  0.50 20,267.21
# neighborhood_target   2,629.03  0.49 19,865.10
# neighborhood_quantile 2,666.86  0.52 19,902.39
# polar_target          2,790.56  0.56 22,530.84
# latlng                2,995.75  0.59 21,425.96
# unit                  3,055.20  0.63 22,509.97
# simple                3,135.44  0.64 22,565.79

# %%
def clip_target(X, y, quantiles=[.05, .95]):
    qinf = y.quantile(quantiles[0])
    qsup = y.quantile(quantiles[1])
    return X, y.clip(lower=qinf, upper=qsup)

exp_clipped_latlon = exp.run('clipped latlng', LGBMRegressor(), {}, simple_pipe_target, preprocess_train_fn=clip_target)

exp_clipped_neighborhood = exp.run('clipped neighborhood', LGBMRegressor(), {}, simple_pipe_neighborhood, preprocess_train_fn=clip_target)

exp.obs_metrics.query('split_name == "test"').groupby(['name', 'metric']).value.median().unstack().sort_values('mae')
# Out:
# metric                     mae  mape      rmse
# name
# clipped latlng        2,463.49  0.28 26,635.30
# clipped neighborhood  2,479.93  0.29 26,648.42
# neighborhood          2,683.82  0.45 23,328.00
# neighborhood_target   2,708.29  0.50 22,990.64
# polar_target          2,761.00  0.49 23,469.87
# neighborhood_quantile 2,782.88  0.54 23,237.33
# latlng                2,997.26  0.55 26,564.81
# unit                  3,125.15  0.60 26,187.60
# simple                3,196.31  0.61 26,214.83

# %%
base = alt.Chart(
    exp.obs_metrics.assign(name = exp.obs_metrics.metric + ' | ' + exp.obs_metrics.name + ' | ' + exp.obs_metrics.split_name).query('metric == "mape"')
)

selection = alt.selection_multi(fields=['name'], bind='legend')
opacity = alt.condition(selection, alt.value(1.0), alt.value(0))

(
    base.mark_point().encode(x = 'split', y = 'value', color = 'name', tooltip = ['name', 'value'], opacity = opacity) + 
    base.mark_line().encode(x = 'split', y = 'value', color = 'name', opacity = opacity)
).add_selection(selection).properties(width=900, height=600).interactive(bind_x = False)
# Out:
# alt.LayerChart(...)

# %%
y_pred = exp_clipped_latlon.predict(X, y)
points = [0] + [i.right for i in pd.qcut(y, 15).cat.categories.values]

pd.DataFrame({
    'true': pd.cut(y, points).tolist(),
    'pred': pd.cut(y_pred, points).tolist()
}).groupby(['true', 'pred'])\
.value_counts().unstack().fillna(0).astype(int)\
.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_c02d6_row0_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_c02d6_row0_col1, #T_c02d6_row1_col1, #T_c02d6_row2_col2, #T_c02d6_row2_col3, #T_c02d6_row3_col4, #T_c02d6_row4_col4, #T_c02d6_row5_col5, #T_c02d6_row6_col5, #T_c02d6_row7_col8, #T_c02d6_row8_col9, #T_c02d6_row9_col9, #T_c02d6_row10_col10, #T_c02d6_row11_col11, #T_c02d6_row12_col12, #T_c02d6_row13_col13, #T_c02d6_row14_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c02d6_row0_col2, #T_c02d6_row5_col3, #T_c02d6_row13_col12 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_c02d6_row0_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c02d6_row0_col4, #T_c02d6_row1_col0, #T_c02d6_row4_col9, #T_c02d6_row10_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c02d6_row0_col5, #T_c02d6_row0_col6, #T_c02d6_row0_col7, #T_c02d6_row0_col9, #T_c02d6_row1_col6, #T_c02d6_row2_col0, #T_c02d6_row2_col7, #T_c02d6_row6_col11, #T_c02d6_row7_col2, #T_c02d6_row9_col3, #T_c02d6_row9_col4, #T_c02d6_row13_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c02d6_row0_col8, #T_c02d6_row3_col8, #T_c02d6_row7_col11 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c02d6_row0_col10, #T_c02d6_row0_col11, #T_c02d6_row1_col10, #T_c02d6_row3_col10, #T_c02d6_row4_col10, #T_c02d6_row4_col11, #T_c02d6_row6_col12, #T_c02d6_row8_col12, #T_c02d6_row9_col2, #T_c02d6_row9_col14, #T_c02d6_row10_col3, #T_c02d6_row11_col5, #T_c02d6_row11_col6, #T_c02d6_row12_col5, #T_c02d6_row12_col6, #T_c02d6_row12_col8, #T_c02d6_row13_col9, #T_c02d6_row14_col11 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c02d6_row0_col12, #T_c02d6_row0_col13, #T_c02d6_row0_col14, #T_c02d6_row1_col8, #T_c02d6_row1_col11, #T_c02d6_row1_col12, #T_c02d6_row1_col13, #T_c02d6_row1_col14, #T_c02d6_row2_col8, #T_c02d6_row2_col10, #T_c02d6_row2_col11, #T_c02d6_row2_col12, #T_c02d6_row2_col13, #T_c02d6_row2_col14, #T_c02d6_row3_col0, #T_c02d6_row3_col11, #T_c02d6_row3_col12, #T_c02d6_row3_col13, #T_c02d6_row3_col14, #T_c02d6_row4_col0, #T_c02d6_row4_col12, #T_c02d6_row4_col13, #T_c02d6_row4_col14, #T_c02d6_row5_col0, #T_c02d6_row5_col11, #T_c02d6_row5_col12, #T_c02d6_row5_col13, #T_c02d6_row5_col14, #T_c02d6_row6_col0, #T_c02d6_row6_col13, #T_c02d6_row6_col14, #T_c02d6_row7_col0, #T_c02d6_row7_col1, #T_c02d6_row7_col13, #T_c02d6_row7_col14, #T_c02d6_row8_col0, #T_c02d6_row8_col2, #T_c02d6_row8_col13, #T_c02d6_row8_col14, #T_c02d6_row9_col0, #T_c02d6_row9_col1, #T_c02d6_row10_col0, #T_c02d6_row10_col1, #T_c02d6_row10_col2, #T_c02d6_row10_col14, #T_c02d6_row11_col0, #T_c02d6_row11_col1, #T_c02d6_row11_col2, #T_c02d6_row11_col3, #T_c02d6_row11_col4, #T_c02d6_row11_col14, #T_c02d6_row12_col0, #T_c02d6_row12_col1, #T_c02d6_row12_col2, #T_c02d6_row12_col3, #T_c02d6_row12_col4, #T_c02d6_row12_col7, #T_c02d6_row13_col0, #T_c02d6_row13_col1, #T_c02d6_row13_col2, #T_c02d6_row13_col3, #T_c02d6_row13_col4, #T_c02d6_row13_col5, #T_c02d6_row13_col6, #T_c02d6_row13_col7, #T_c02d6_row13_col8, #T_c02d6_row14_col0, #T_c02d6_row14_col1, #T_c02d6_row14_col2, #T_c02d6_row14_col3, #T_c02d6_row14_col4, #T_c02d6_row14_col5, #T_c02d6_row14_col6, #T_c02d6_row14_col7, #T_c02d6_row14_col8, #T_c02d6_row14_col9, #T_c02d6_row14_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c02d6_row1_col2, #T_c02d6_row4_col5 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_c02d6_row1_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_c02d6_row1_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_c02d6_row1_col5, #T_c02d6_row4_col1, #T_c02d6_row6_col10, #T_c02d6_row9_col12, #T_c02d6_row11_col8, #T_c02d6_row13_col11 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c02d6_row1_col7, #T_c02d6_row1_col9, #T_c02d6_row2_col9, #T_c02d6_row3_col9, #T_c02d6_row6_col1, #T_c02d6_row7_col12, #T_c02d6_row8_col1, #T_c02d6_row9_col13, #T_c02d6_row10_col4, #T_c02d6_row11_col7, #T_c02d6_row12_col14 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c02d6_row2_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_c02d6_row2_col4, #T_c02d6_row5_col4 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_c02d6_row2_col5 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c02d6_row2_col6, #T_c02d6_row7_col3, #T_c02d6_row10_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c02d6_row3_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c02d6_row3_col2 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_c02d6_row3_col3 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_c02d6_row3_col5 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_c02d6_row3_col6, #T_c02d6_row9_col7 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_c02d6_row3_col7, #T_c02d6_row8_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c02d6_row4_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_c02d6_row4_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_c02d6_row4_col6 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_c02d6_row4_col7, #T_c02d6_row7_col10, #T_c02d6_row11_col9, #T_c02d6_row13_col14 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c02d6_row4_col8, #T_c02d6_row6_col2, #T_c02d6_row12_col9 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_c02d6_row5_col1, #T_c02d6_row5_col10, #T_c02d6_row10_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c02d6_row5_col2, #T_c02d6_row11_col13 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c02d6_row5_col6 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_c02d6_row5_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_c02d6_row5_col8 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_c02d6_row5_col9 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c02d6_row6_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_c02d6_row6_col4 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_c02d6_row6_col6 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_c02d6_row6_col7 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_c02d6_row6_col8 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_c02d6_row6_col9 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_c02d6_row7_col4, #T_c02d6_row8_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_c02d6_row7_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_c02d6_row7_col6 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_c02d6_row7_col7 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_c02d6_row7_col9 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_c02d6_row8_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_c02d6_row8_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_c02d6_row8_col7 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_c02d6_row8_col8 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_c02d6_row8_col10, #T_c02d6_row12_col11 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_c02d6_row8_col11, #T_c02d6_row12_col10 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_c02d6_row9_col5, #T_c02d6_row14_col12 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c02d6_row9_col6 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_c02d6_row9_col8 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_c02d6_row9_col10 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_c02d6_row9_col11 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_c02d6_row10_col8 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_c02d6_row10_col9 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_c02d6_row10_col11 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_c02d6_row10_col12 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_c02d6_row10_col13 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c02d6_row11_col10 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_c02d6_row11_col12 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_c02d6_row12_col13 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_c02d6_row14_col13 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c02d

# %%
pd.DataFrame({
    'feature': sum(exp_clipped_latlon.model[:-1][0]._columns, []),
    'imp': exp_clipped_latlon.model._final_estimator.feature_importances_
}).sort_values('imp', ascending=False)
# Out:
#           feature   imp
# 0     usable_area  1014
# 4             lat   431
# 5             lon   371
# 6    neighborhood   371
# 2       bathrooms   285
# 3  parking_spaces   238
# 1        bedrooms   198
# 7      unit_types    92

# %%
import m2cgen as m2c

code = m2c.export_to_go(exp_clipped_neighborhood.model._final_estimator, function_name='Predict')
code
# Out:
# 'func Predict(input []float64) float64 {\n    var var0 float64\n    if input[0] > 220.50000000000003 {\n        if input[9] > 0.000000000000000000000000000000000010000000180025095 {\n            if input[0] > 465.50000000000006 {\n                var0 = 8848.792385028028\n            } else {\n                if input[52] > 0.000000000000000000000000000000000010000000180025095 {\n                    if input[0] > 310.50000000000006 {\n                        var0 = 8321.402760801138\n                    } else {\n                        var0 = 7862.339542949686\n                    }\n                } else {\n                    if input[0] > 250.50000000000003 {\n                        var0 = 8644.104809142893\n                    } else {\n                        var0 = 8211.766526556768\n                    }\n                }\n            }\n        } else {\n            if input[0] > 339.50000000000006 {\n                if input[5] <= -43.48908424377441 {\n                    if input[4] <= -23.017276763916012 {\n                        var0 = 7954.687068634724\n                    } else {\n                        var0 = 8634.872447090638\n                    }\n                } else {\n                    if input[0] > 562.0000000000001 {\n                        var0 = 8093.528599837869\n                    } else {\n                        if input[47] > 0.000000000000000000000000000000000010000000180025095 {\n                            var0 = 7039.478359318662\n                        } else {\n                            if input[48] > 0.000000000000000000000000000000000010000000180025095 {\n                                var0 = 7232.697231883956\n                            } else {\n                                if input[4] <= -23.018260002136227 {\n                                    var0 = 7226.345970024482\n                                } else {\n                                    if input[2] > 5.500000000000001 {\n                                        var0 = 8045.299236462396\n                                    } else {\n                                        if input[51] > 0.000000000000000000000000000000000010000000180025095 {\n                                            var0 = 8015.830768261513\n                                        } else {\n                                            var0 = 7536.437584916459\n                                        }\n                                    }\n                                }\n                            }\n                        }\n                    }\n                }\n            } else {\n                if input[2] > 4.500000000000001 {\n                    if input[48] > 0.000000000000000000000000000000000010000000180025095 {\n                        var0 = 7128.374047336544\n                    } else {\n                        var0 = 7659.315987793219\n                    }\n                } else {\n                    if input[22] > 0.000000000000000000000000000000000010000000180025095 {\n                        var0 = 7732.943014691976\n                    } else {\n                        if input[18] > 0.000000000000000000000000000000000010000000180025095 {\n                            var0 = 7537.499845242147\n                        } else {\n                            var0 = 7096.327396591847\n                        }\n                    }\n                }\n            }\n        }\n    } else {\n        if input[0] > 120.50000000000001 {\n            if input[9] > 0.000000000000000000000000000000000010000000180025095 {\n                if input[3] > 2.5000000000000004 {\n                    var0 = 7783.621183875173\n                } else {\n                    if input[1] > 1.5000000000000002 {\n                        var0 = 7406.6510637350075\n                    } else {\n                        var0 = 7996.245988645377\n                    }\n                }\n            } else {\n                if input[18 ...
